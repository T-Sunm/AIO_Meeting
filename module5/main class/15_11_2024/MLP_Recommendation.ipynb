# %%
'''
Activation: GELU
Optimizer: Adam
Initialization: he init
Normalization: [0,1], [-1,1]
'''



import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms

# Check if GPU is available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
#device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")

# %% [markdown]
# #### Data

# %%
# Load CFashionMNIST dataset
transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])

trainset = torchvision.datasets.FashionMNIST(root='data', train=True, download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=512, num_workers=10, shuffle=True)

testset = torchvision.datasets.FashionMNIST(root='data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=512, num_workers=10, shuffle=False)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to display the images
def imshow(img):
    img = img*0.5 + 0.5
    np_img = img.numpy()
    plt.imshow(np.transpose(np_img, (1, 2, 0)))
    plt.show()

for i, (images, labels) in enumerate(trainloader, 0):
    # Plot some images
    imshow(torchvision.utils.make_grid(images[:8]))  # Display 8 images from the batch
    break

# %% [markdown]
# #### Model

# %%
model = nn.Sequential(
    nn.Flatten(), 
    nn.Linear(784, 256),
    nn.GELU(),
    nn.Linear(256, 256),
    nn.GELU(),
    nn.Linear(256, 10)
)
model = model.to(device)

print(model)
# Out:
# Sequential(
#   (0): Flatten(start_dim=1, end_dim=-1)
#   (1): Linear(in_features=784, out_features=256, bias=True)
#   (2): GELU(approximate='none')
#   (3): Linear(in_features=256, out_features=256, bias=True)
#   (4): GELU(approximate='none')
#   (5): Linear(in_features=256, out_features=10, bias=True)
# )

# %%
# Generating a random tensor
input_tensor = torch.rand(5, 28, 28).to(device)

# Feeding the tensor into the model
output = model(input_tensor)
print(output.shape)
# Out:
# torch.Size([5, 10])

# %% [markdown]
# #### Loss, Optimizer, and Evaluation Function

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters())

# %%
# Function to compute loss and accuracy for test set
def evaluate(model, testloader, criterion):
    model.eval()
    test_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in testloader:
            # Move inputs and labels to the device
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)
            test_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    test_loss = test_loss / len(testloader)
    return test_loss, accuracy

# %%
test_loss, test_accuracy = evaluate(model, testloader, criterion)
print(f'test_loss: {test_loss}')
print(f'test_accuracy: {test_accuracy}')
# Out:
# test_loss: 2.3082818150520326
# test_accuracy: 9.9

# %% [markdown]
# #### Train

# %%
# some parameter
train_losses = []
train_accuracies = []
test_losses = []
test_accuracies = []
max_epoch = 100

# %%
# train
for epoch in range(max_epoch):
    running_loss = 0.0
    running_correct = 0   # to track number of correct predictions
    total = 0             # to track total number of samples

    for i, (inputs, labels) in enumerate(trainloader, 0):
        # Move inputs and labels to the device
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, labels)
        running_loss += loss.item()

        # Determine class predictions and track accuracy
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        running_correct += (predicted == labels).sum().item()

        # Backward pass and optimization
        loss.backward()
        optimizer.step()        

    epoch_accuracy = 100 * running_correct / total
    epoch_loss = running_loss / (i + 1)
    test_loss, test_accuracy = evaluate(model, testloader, criterion)
    print(f"Epoch [{epoch + 1}/{max_epoch}], Loss: {epoch_loss:.4f}, Accuracy: {epoch_accuracy:.2f}%, Test Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.2f}%")
    
    # save for plot
    train_losses.append(epoch_loss)
    train_accuracies.append(epoch_accuracy)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)
# Out:
# Epoch [1/100], Loss: 0.6168, Accuracy: 78.28%, Test Loss: 0.4879, Test Accuracy: 81.92%
# Epoch [2/100], Loss: 0.4031, Accuracy: 85.42%, Test Loss: 0.4097, Test Accuracy: 85.36%
# Epoch [3/100], Loss: 0.3608, Accuracy: 86.91%, Test Loss: 0.3882, Test Accuracy: 85.92%
# Epoch [4/100], Loss: 0.3261, Accuracy: 88.03%, Test Loss: 0.3620, Test Accuracy: 86.74%
# Epoch [5/100], Loss: 0.3070, Accuracy: 88.75%, Test Loss: 0.3521, Test Accuracy: 87.11%
# Epoch [6/100], Loss: 0.2921, Accuracy: 89.14%, Test Loss: 0.3392, Test Accuracy: 87.52%
# Epoch [7/100], Loss: 0.2728, Accuracy: 89.87%, Test Loss: 0.3367, Test Accuracy: 87.83%
# Epoch [8/100], Loss: 0.2581, Accuracy: 90.48%, Test Loss: 0.3682, Test Accuracy: 86.73%
# Epoch [9/100], Loss: 0.2489, Accuracy: 90.80%, Test Loss: 0.3257, Test Accuracy: 88.26%
# Epoch [10/100], Loss: 0.2372, Accuracy: 91.24%, Test Loss: 0.3400, Test Accuracy: 87.92%
# Epoch [11/100], Loss: 0.2330, Accuracy: 91.31%, Test Loss: 0.3246, Test Accuracy: 88.36%
# Epoch [12/100], Loss: 0.2116, Accuracy: 92.21%, Test Loss: 0.3229, Test Accuracy: 88.60%
# Epoch [13/100], Loss: 0.2058, Accuracy: 92.41%, Test Loss: 0.3307, Test Accuracy: 88.34%
# Epoch [14/100], Loss: 0.1983, Accuracy: 92.59%, Test Loss: 0.3407, Test Accuracy: 87.85%
