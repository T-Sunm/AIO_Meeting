# %%
import torch
from torch import nn
import numpy as np
from torchvision.utils import save_image

device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# # 1. Dataset

# %%
import torchvision

img_size = 32
num_classes = 10

# %%
transform = torchvision.transforms.Compose([
    torchvision.transforms.Resize((img_size, img_size)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize(mean=[0.5], std=[0.5])
])

mnist_images = torchvision.datasets.MNIST(root='mnist_data', train=True, 
                                    download=True, transform=transform)

# %%
from torch.utils.data import DataLoader

BATCH_SIZE = 32
dataloader = DataLoader(mnist_images, batch_size=BATCH_SIZE, shuffle=True)

# %% [markdown]
# # 2. Model

# %%
channels = 1
img_shape = (channels, img_size, img_size)
latent_dim = 100

# %%
class Generator(nn.Module):
    def __init__(self, num_classes, emb_dim):
        super().__init__()

        self.label_emb = nn.Embedding(num_classes, emb_dim) 
        
        self.model = nn.Sequential(
            nn.Linear(latent_dim + emb_dim, 256),
            nn.BatchNorm1d(256,),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(256, 512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(512, 1024),
            nn.BatchNorm1d(1024),
            nn.LeakyReLU(0.2, inplace=True),
        
            nn.Linear(1024, int(np.prod(img_shape))),
            nn.Tanh()
        )
        
    def forward(self, z, label):
        cond = self.label_emb(label)
        x = torch.cat([z, cond], 1)
        img = self.model(x)
        img = img.view(img.size(0), *img_shape)
        return img

# %%
class Descriminator(nn.Module):
    def __init__(self, num_classes, emb_dim):
        super().__init__()

        self.label_emb = nn.Embedding(num_classes, emb_dim) 

        self.model = nn.Sequential(
            nn.Linear(int(np.prod(img_shape))+emb_dim, 512),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            
            nn.Linear(256, 1),
            nn.Sigmoid()
        )
        
    def forward(self, img, label):
        img_flat = img.view(img.size(0), -1)
        cond = self.label_emb(label)
        x = torch.cat([img_flat, cond], 1)
        validity = self.model(x)
        return validity

# %%
generator = Generator(num_classes=num_classes, emb_dim=16)
discriminator = Descriminator(num_classes=num_classes, emb_dim=16)

# %%
generator.to(device)
# Out:
# Generator(
#   (label_emb): Embedding(10, 16)
#   (model): Sequential(
#     (0): Linear(in_features=116, out_features=256, bias=True)
#     (1): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): LeakyReLU(negative_slope=0.2, inplace=True)
#     (3): Linear(in_features=256, out_features=512, bias=True)
#     (4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): LeakyReLU(negative_slope=0.2, inplace=True)
#     (6): Linear(in_features=512, out_features=1024, bias=True)
#     (7): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): LeakyReLU(negative_slope=0.2, inplace=True)
#     (9): Linear(in_features=1024, out_features=1024, bias=True)
#     (10): Tanh()
#   )
# )

# %%
discriminator.to(device)
# Out:
# Descriminator(
#   (label_emb): Embedding(10, 16)
#   (model): Sequential(
#     (0): Linear(in_features=1040, out_features=512, bias=True)
#     (1): LeakyReLU(negative_slope=0.2, inplace=True)
#     (2): Linear(in_features=512, out_features=256, bias=True)
#     (3): LeakyReLU(negative_slope=0.2, inplace=True)
#     (4): Linear(in_features=256, out_features=1, bias=True)
#     (5): Sigmoid()
#   )
# )

# %% [markdown]
# # 3. Training

# %%
import os
os.makedirs("images_cGAN", exist_ok=True)

save_interval = 10

# %%
EPOCHS = 200

optimizer_G = torch.optim.Adam(generator.parameters(), lr=0.0001)
optimizer_D = torch.optim.Adam(discriminator.parameters(), lr=0.0002)

criterion = nn.BCELoss()
hist = {
        "train_G_loss": [],
        "train_D_loss": [],
}

# %%
for epoch in range(EPOCHS):
    running_G_loss = 0.0
    running_D_loss = 0.0

    for i, (imgs, labels) in enumerate(dataloader):
        real_imgs = imgs.to(device)
        labels = labels.to(device)
        
        real_labels = torch.ones((imgs.shape[0], 1)).to(device)
        fake_labels = torch.zeros((imgs.shape[0], 1)).to(device)


        # -------------------------- Train Generator --- 
        optimizer_G.zero_grad()
        
        # Noise input for Generator
        z = torch.randn((imgs.shape[0], latent_dim)).to(device)

        gen_imgs = generator(z, labels)
        validity = discriminator(gen_imgs, labels)
        G_loss = criterion(validity, real_labels)
        running_G_loss += G_loss.item()

        G_loss.backward()
        optimizer_G.step()


        # -------------- Train Discriminator --- 
        optimizer_D.zero_grad()

        real_validity = discriminator(real_imgs, labels)
        real_loss = criterion(real_validity, real_labels)

        fake_validity = discriminator(gen_imgs.detach(), labels)
        fake_loss = criterion(fake_validity, fake_labels)
        
        D_loss = (real_loss + fake_loss) / 2
        running_D_loss += D_loss.item()

        D_loss.backward()
        optimizer_D.step()
    
    epoch_G_loss = running_G_loss / len(dataloader)
    epoch_D_loss = running_D_loss / len(dataloader)
    
    print(f"Epoch [{epoch + 1}/{EPOCHS}], Train G Loss: {epoch_G_loss:.4f}, Train D Loss: {epoch_D_loss:.4f}")

    hist["train_G_loss"].append(epoch_G_loss)
    hist["train_D_loss"].append(epoch_D_loss)

    if epoch % save_interval == 0:
        save_image(gen_imgs.data[:25], f"images_cGAN/epoch_{epoch}.png", nrow=5, normalize=True)
# Out:
# Epoch [1/200], Train G Loss: 9.2417, Train D Loss: 0.0737
# Epoch [2/200], Train G Loss: 6.0803, Train D Loss: 0.1232
# Epoch [3/200], Train G Loss: 4.1206, Train D Loss: 0.1548
# Epoch [4/200], Train G Loss: 4.0571, Train D Loss: 0.1652
# Epoch [5/200], Train G Loss: 3.7233, Train D Loss: 0.1721
# Epoch [6/200], Train G Loss: 3.9440, Train D Loss: 0.1537
# Epoch [7/200], Train G Loss: 3.8221, Train D Loss: 0.1685
# Epoch [8/200], Train G Loss: 3.8435, Train D Loss: 0.1702
# Epoch [9/200], Train G Loss: 3.7482, Train D Loss: 0.1741
# Epoch [10/200], Train G Loss: 3.4311, Train D Loss: 0.2106
# Epoch [11/200], Train G Loss: 3.3929, Train D Loss: 0.2237
# Epoch [12/200], Train G Loss: 3.2597, Train D Loss: 0.2341
# Epoch [13/200], Train G Loss: 3.0157, Train D Loss: 0.2735
# Epoch [14/200], Train G Loss: 2.9022, Train D Loss: 0.2819
# Epoch [15/200], Train G Loss: 2.9256, Train D Loss: 0.2863
# Epoch [16/200], Train G Loss: 2.8750, Train D Loss: 0.2895
# Epoch [17/200], Train G Loss: 2.8156, Train D Loss: 0.3008
# Epoch [18/200], Train G Loss: 2.8302, Train D Loss: 0.2966
# Epoch [19/200], Train G Loss: 2.7855, Train D Loss: 0.2991
# Epoch [20/200], Train G Loss: 2.8446, Train D Loss: 0.3016
# Epoch [21/200], Train G Loss: 2.6451, Train D Loss: 0.3256
# Epoch [22/200], Train G Loss: 2.4537, Train D Loss: 0.3384
# Epoch [23/200], Train G Loss: 2.3041, Train D Loss: 0.3435
# Epoch [24/200], Train G Loss: 2.0815, Train D Loss: 0.3868
# Epoch [25/200], Train G Loss: 1.9808, Train D Loss: 0.3994
# Epoch [26/200], Train G Loss: 1.8813, Train D Loss: 0.4183
# Epoch [27/200], Train G Loss: 1.8336, Train D Loss: 0.4212
# Epoch [28/200], Train G Loss: 1.7990, Train D Loss: 0.4350
# Epoch [29/200], Train G Loss: 1.7019, Train D Loss: 0.4537
# Epoch [30/200], Train G Loss: 1.6778, Train D Loss: 0.4532
# Epoch [31/200], Train G Loss: 1.6284, Train D Loss: 0.4632
# Epoch [32/200], Train G Loss: 1.6212, Train D Loss: 0.4646
# Epoch [33/200], Train G Loss: 1.5810, Train D Loss: 0.4716
# Epoch [34/200], Train G Loss: 1.5648, Train D Loss: 0.4738
# Epoch [35/200], Train G Loss: 1.5661, Train D Loss: 0.4755
# Epoch [36/200], Train G Loss: 1.5550, Train D Loss: 0.4736
# Epoch [164/200], Train G Loss: 4.1555, Train D Loss: 0.1839
# Epoch [165/200], Train G Loss: 4.2100, Train D Loss: 0.1704
# Epoch [166/200], Train G Loss: 4.2024, Train D Loss: 0.1740
# Epoch [167/200], Train G Loss: 4.1628, Train D Loss: 0.1810
# Epoch [168/200], Train G Loss: 4.0397, Train D Loss: 0.1942
# Epoch [169/200], Train G Loss: 4.2040, Train D Loss: 0.1777
# Epoch [170/200], Train G Loss: 4.1234, Train D Loss: 0.1911
# Epoch [171/200], Train G Loss: 4.2015, Train D Loss: 0.1734
# Epoch [172/200], Train G Loss: 4.2395, Train D Loss: 0.1664
# Epoch [173/200], Train G Loss: 4.1440, Train D Loss: 0.1765
# Epoch [174/200], Train G Loss: 4.1934, Train D Loss: 0.1723
# Epoch [175/200], Train G Loss: 4.1650, Train D Loss: 0.1805
# Epoch [176/200], Train G Loss: 4.1778, Train D Loss: 0.1842
# Epoch [177/200], Train G Loss: 4.2533, Train D Loss: 0.1701
# Epoch [178/200], Train G Loss: 4.2509, Train D Loss: 0.1728
# Epoch [179/200], Train G Loss: 4.2616, Train D Loss: 0.1788
# Epoch [180/200], Train G Loss: 4.2089, Train D Loss: 0.1816
# Epoch [181/200], Train G Loss: 4.3386, Train D Loss: 0.1614
# Epoch [182/200], Train G Loss: 4.2799, Train D Loss: 0.1779
# Epoch [183/200], Train G Loss: 4.2038, Train D Loss: 0.1785
# Epoch [184/200], Train G Loss: 4.2731, Train D Loss: 0.1650
# Epoch [185/200], Train G Loss: 4.3315, Train D Loss: 0.1664
# Epoch [186/200], Train G Loss: 4.3091, Train D Loss: 0.1677
# Epoch [187/200], Train G Loss: 4.2121, Train D Loss: 0.1686
# Epoch [188/200], Train G Loss: 4.1396, Train D Loss: 0.1759
# Epoch [189/200], Train G Loss: 4.1962, Train D Loss: 0.1774
# Epoch [190/200], Train G Loss: 4.2583, Train D Loss: 0.1764
# Epoch [191/200], Train G Loss: 4.2847, Train D Loss: 0.1794
# Epoch [192/200], Train G Loss: 4.3041, Train D Loss: 0.1676
# Epoch [193/200], Train G Loss: 4.3108, Train D Loss: 0.1686
# Epoch [194/200], Train G Loss: 4.2638, Train D Loss: 0.1731
# Epoch [195/200], Train G Loss: 4.2947, Train D Loss: 0.1746
# Epoch [196/200], Train G Loss: 4.3063, Train D Loss: 0.1663
# Epoch [197/200], Train G Loss: 4.3428, Train D Loss: 0.1660
# Epoch [198/200], Train G Loss: 4.4404, Train D Loss: 0.1569
# Epoch [199/200], Train G Loss: 4.3142, Train D Loss: 0.1723
# Epoch [200/200], Train G Loss: 4.3666, Train D Loss: 0.1591

# %% [markdown]
# # 4. Inference

# %%
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

# %%
generator.eval()

num_sample = 5
for i in range(num_classes):
    target_class = i
    z = torch.randn((num_sample, latent_dim)).to(device)
    condition_labels = torch.full((num_sample,), target_class, dtype=torch.long).to(device)

    gen_imgs = generator(z, condition_labels).detach().cpu()

    grid = make_grid(gen_imgs, nrow=num_sample, normalize=True).permute(1,2,0).numpy()
    plt.imshow(grid)
    plt.show()
